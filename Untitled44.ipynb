# %% [markdown]
# <a href="https://colab.research.google.com/github/Nagavalleswari/Data-Science/blob/main/Untitled44.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import requests
import pandas as pd

# %%
url = 'https://api.github.com/repos/pandas-dev/pandas/issues'

# %%
response=requests.get(url)
issues=response.json()

# %%
df_issues=pd.DataFrame(issues)

# %%
print(df_issues[['id', 'title', 'state', 'created_at']].head())
# Out:
#            id                                              title state  \
# 0  4935238404  BUG: assert_almost_equal not respecting atol/r...  open
# 1  4935053752  BUG: merge on NaN-labeled join key produced du...  open
# 2  4934378560  BUG: unique/factorize returning wrong results ...  open
# 3  4934135758  BUG: setitem-with-expansion not retaining date...  open
# 4  4933590267  BUG: register_option can clobber an existing o...  open
#
#              created_at
# 0  2026-07-21T03:56:54Z
# 1  2026-07-21T03:20:19Z
# 2  2026-07-21T01:05:46Z
# 3  2026-07-21T00:20:25Z
# 4  2026-07-20T22:30:18Z

# %%
import sqlite3
import pandas as pd

# %%
conn = sqlite3.connect("students.db")
cursor = conn.cursor()

# %%
cursor.execute('''CREATE TABLE IF NOT EXISTS students (id INTEGER, name TEXT)''')

# %%
cursor.execute("INSERT INTO students VALUES (1, 'John')")
conn.commit()

# %%
cursor.execute("INSERT INTO students VALUES (2, 'Joy')")
conn.commit()

# %%
df = pd.read_sql_query("SELECT * FROM students", conn)
print(df)
# Out:
#    id  name
# 0   1  John
# 1   2   Joy

# %%
cursor.execute("UPDATE students SET name = 'Alice' WHERE id = 1")
cursor.execute("DELETE FROM students WHERE id = 1")
conn.commit()
conn.close()
